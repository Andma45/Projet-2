# %%
import pandas as pd
import numpy as np

# %%
df_movie = pd.read_pickle("df_movies_compl_overview_fr.pkl")

# %%
df_movie = df_movie.drop(columns="overview")

# %%
df_movie.head()
# Out:
#       tconst  averageRating  numVotes  isAdult  startYear  runtimeMinutes  \
# 0  tt0010323            8.0     69954    False       1920              67
# 1  tt0012349            8.2    134613    False       1921              68
# 2  tt0013442            7.9    105273    False       1922              94
# 3  tt0014429            8.1     22875    False       1923              74
# 4  tt0015648            7.9     61385    False       1925              66
#
#                               genres                           title  budget  \
# 0  ['Horror', 'Mystery', 'Thriller']  Le Cabinet du docteur Caligari   18000
# 1      ['Comedy', 'Drama', 'Family']                          Le Kid  250000
# 2              ['Fantasy', 'Horror']            Nosferatu le vampire       0
# 3   ['Action', 'Comedy', 'Thriller']                Monte là-dessus!  121000
# 4   ['Drama', 'History', 'Thriller']           Le cuirassé Potemkine       0
#
# ...
